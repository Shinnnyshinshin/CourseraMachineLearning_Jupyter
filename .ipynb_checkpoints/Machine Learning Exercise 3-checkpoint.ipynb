# %% [markdown]
# # Machine Learning Exercise 3 - Multi-Class Classification

# %% [markdown]
# This exercise will be an implementation of a one-vs-all logistic regression and neural network to recognize hand-written digits. It will be an extension of the logistic regression that was written for exercise 2, and applied to the one-vs-all classification.
#
# The dataset is ex3data.mat that contains 5000 training examples of handwritten digits.
#
# The data is in MATLAB / OCTAVE native format, which can be converted into a python-readable format using a SciPy utility.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import loadmat

from scipy.optimize import fmin_cg

# %matplotlib inline

data = loadmat('ex3_data/ex3data1.mat')
data

X = data['X']
y = data['y'].flatten()

# replace 10-->0
y[np.flatnonzero(y==10)] = 0

# %%
def displayData(X):
    
    # set up array
    fig, axarr = plt.subplots(nrows=10, ncols=10,
                              figsize=(10,10))
    
    # loop over randomly drawn numbers
    for ii in range(10):
        for jj in range(10):
            ind = np.random.randint(X.shape[0])
            tmp = X[ind,:].reshape(20,20, order='F')
            axarr[ii,jj].imshow(tmp, cmap='gray_r')
            plt.setp(axarr[ii,jj].get_xticklabels(), visible=False)
            plt.setp(axarr[ii,jj].get_yticklabels(), visible=False)
    
    fig.subplots_adjust(hspace=0, wspace=0)

# %%
displayData(X)

# %%
data['X'].shape, data['y'].shape
# Out:
# ((5000, 400), (5000, 1))

# %% [markdown]
# So each of the images are represented in a 400-dimensional vector. The 400 "features" are grayscale intensities of each pixel in the original 20 x 20 image. The class labels are in the vector y as a number representing the image. Let's see what it looks like

# %%
temp = np.matrix(data['X']) # extracting the X values
first_example = temp[4488,:] # just a random index
first_example_reshaped = first_example.reshape(20,20) # reshaping the list as 20 x 20 array

# %%
plt.imshow(first_example_reshaped) # here's what it looks like

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def cost_regularized(theta, X, y, lam):
    
    # let's first make an array of the lambdas
    lambda_array = np.ones(len(theta)) * lam
    
    # zero-out the first element so that we dont regularize the contstant term
    lambda_array[0] = 0.0
    
    # num of training examples
    m = len(y)
    
    # tolerance for the sigmoid function
    # this is necessary to eliminate errors when using 
    eps = 1e-15 
    # compute the  hypothesis 
    
    htheta = sigmoid(np.dot(X, theta))
    
    # the J is split into 3 terms
    term1 = np.dot(np.log(htheta), y)
    term2 = np.dot(np.log(1-htheta+eps), (1-y))
    term3 = 1/2 * np.sum(lambda_array*theta**2)
    
    # cost function
    J = -1/m * (term1 + term2 - term3)
    return (J)

# %%
def compute_gradient_dec_regularized(theta, X, y, lam):
    # make array of lambdas
    
    # let's first make an array of the lambdas
    lambda_array = np.ones(len(theta)) * lam
    
    # zero-out the first element so that we dont regularize the contstant term
    lambda_array[0] = 0.0
    
    # num of training examples
    m = len(y)
    
    # compute hypothesis 
    htheta = sigmoid(np.dot(X, theta))
    
    # gradient
    grad = (np.dot(X.T, (htheta - y)) + lambda_array * theta) /m 
    return (grad)

# %%
def cost_function_regularized(theta, X, y, lam):
    # return the results of the above two functions
    J = cost_regularized(theta, X, y, lam)
    
    # gradient function
    grad = compute_gradient_dec_regularized(theta, X, y, lam)
    
    return J, grad

# %% [markdown]
# Next we need the function that computes the gradient. Again, we already defined this in the previous exercise

# %% [markdown]
# ## One-vs-all prediction
#
#
# One-vs-all classification is performed by training multiple regularized logistic regression classifiers.. one for each of the K classes in our dataset (10 in our case).  The function will return all the classifier parameters in a matrix where each row correponds to the learned logistic parameters for one class.

# %%
def oneVsAll(X, y, num_labels, lam):
    
    # sizes
    m, n = X.shape
    
    # parameter array
    all_theta = np.zeros((num_labels, n+1))
    
    # add ones to X data matrix
    X = np.hstack((np.ones((m, 1)), X))
    
    # labels
    labels = np.arange(0, 10)
    
    for ct, lab in enumerate(labels):
        
        ynew = np.array(y==lab, dtype='int').flatten()
        
        # set up bfgs minimization for label
        all_theta[ct,:] = fmin_cg(cost_regularized, all_theta[ct,:], 
                                    fprime=compute_gradient_dec_regularized, maxiter=9000, 
                                    args=(X, ynew, lam), disp=False)
        
    return all_theta

# %%
def predictOneVsAll(all_theta, X):
    
    # sizes
    m, n = X.shape
    
    # add ones to X data matrix
    X = np.hstack((np.ones((m, 1)), X))
    
    # model
    htheta = sigmoid(np.dot(X, all_theta.T))
    
    # return the model index
    p = np.argmax(htheta, axis=1)
    
    return p

# %%
# train one-vs-all classifier
lam = 0.1
all_theta = oneVsAll(X, y, 10, lam)

# %%
# get predictions for each set
p = predictOneVsAll(all_theta, X)

# %%
# accuracy is 96.46#: )
print( np.mean(p==y)*100)
# Out:
# 96.46000000000001

# %%
# find the incorrect examples and plot them
ic = np.flatnonzero(p!=y)
plt.hist(y[ic], len(np.unique(y[ic])), range=(-0.5, 9.5))
plt.xlim(-0.5, 9.5)
plt.xlabel('Indicator')
plt.ylabel('Number incorrect')
# Out:
# Text(0, 0.5, 'Number incorrect')

# %% [markdown]
# So the number 0, 1, 4, 6 are all done really acurately, wheras 2,3,8,9 were not (even though there were very few errors).
#
# What sort of questions remain?
#
# * does the numbers complexity have something to do with the accuracy?
# * are certain numbers inherenetly more "varied"? (there is really only 1 way to write '1', but you can imagine a lot more variations for 2.. what are the driving forces behind the errors

# %% [markdown]
# ## A few more notes on the regularized cost function
#
#
# http://codewithmax.com/2017/10/11/machine-learning-programming-exercise-2-logistic-regression/

# %% [markdown]
# # Neural Networks
#
# Multi-class logistic regression cannot form more complex hypothesis because it is a linear classifier.
#
# This week's exercise has to do with a feed forward propagation algorithm that will use already calculated weights for prediction using feedforward propagation algorithm.
#
#
# ### is the sigmoid function used in neural networks related to the logistic function ?
#
# $$
# f(x) =\frac{L}{1+e^{-k(x-x_{0})}}
# $$
# This is the logistic function
#
# $$
# S(t) =\frac{1}{1+e^{-t}}
# $$
# This is the sigmoid function is a special case when L, the threshold limit is 1, the constant from the integration is 1, and the proportionality constant is 1

# %%
import scipy.io as si

# read in pre-computed weights
a = si.loadmat('ex3_data/ex3weights.mat')
Theta1 = a['Theta1']
Theta2 = a['Theta2']

# %%
# read in data again but this time don't change 10 -> 0
a = si.loadmat('ex3_data/ex3data1.mat')
X = a['X']
y = a['y'].flatten()

# %%
def predict(Theta1, Theta2, X):
    
    # sizes
    m, n = X.shape
    num_labels = Theta2.shape[0]
    
    # add ones to X data matrix
    X = np.hstack((np.ones((m, 1)), X))
        
    # hidden layer
    z2 = np.dot(X, Theta1.T)
    a2 = sigmoid(z2)

    #add bias unit to a2
    a2 = np.hstack((np.ones((a2.shape[0],1)), a2))

    # output layer
    z3 = np.dot(a2, Theta2.T)
    a3 = sigmoid(z3)

    p = np.argmax(a3, axis=1)
    
    return p

# %%
p = predict(Theta1, Theta2, X)

# %%
print('Training set Accuracy: %2.2f percent' % (np.mean(p+1==y)*100))
# Out:
# Training set Accuracy: 97.52 percent
